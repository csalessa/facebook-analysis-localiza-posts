# %%
import csv

# %%
import pandas as pd

# %%
data= pd.read_csv("FacebookLocaliza.csv", index_col=0)
data
# Out:
#                                  comments  \
# alt
# NaN                                   1.0
# NaN                                  16.0
# NaN                                  20.0
# NaN                                  75.0
# NaN                                  22.0
# ...                                   ...
# NaN                                 906.0
# NaN                                  13.0
# NaN                                 113.0
# No photo description available.       3.0
# Localiza's photo.                    27.0
#
#                                                           facebookUrl  \
# alt
# NaN                              https://pt-br.facebook.com/Localiza/
# NaN                              https://pt-br.facebook.com/Localiza/
# NaN                              https://pt-br.facebook.com/Localiza/
# NaN                              https://pt-br.facebook.com/Localiza/
# NaN                              https://pt-br.facebook.com/Localiza/
# ...

# %%
data.columns
# Out:
# Index(['comments', 'facebookUrl', 'images/0/thumb', 'images/1/thumb',
#        'images/2/thumb', 'isVideo', 'likes', 'link', 'pageId', 'postId',
#        'shares', 'text', 'thumb', 'time', 'timestamp', 'topLevelUrl',
#        'translatedText', 'url'],
#       dtype='object')

# %%
data.likes
# Out:
# alt
# NaN                                    2
# NaN                                   65
# NaN                                  157
# NaN                                 1400
# NaN                                   92
#                                    ...
# NaN                                19000
# NaN                                 4200
# NaN                                26000
# No photo description available.      235
# Localiza's photo.                    554
# Name: likes, Length: 1000, dtype: int64

# %%
likes = data.likes
likes.max()
# Out:
# 30000

# %%
data["time"].head()
# Out:
# alt
# NaN    Wednesday, January 4, 2023 at 10:06 AM
# NaN     Monday, December 26, 2022 at 11:36 AM
# NaN    Tuesday, December 20, 2022 at 11:11 AM
# NaN      Monday, December 19, 2022 at 6:43 AM
# NaN    Thursday, December 15, 2022 at 6:16 AM
# Name: time, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, nan to Localiza's photo.
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   comments        976 non-null    float64
#  1   facebookUrl     1000 non-null   object
#  2   images/0/thumb  66 non-null     object
#  3   images/1/thumb  3 non-null      object
#  4   images/2/thumb  1 non-null      object
#  5   isVideo         646 non-null    object
#  6   likes           1000 non-null   int64
#  7   link            338 non-null    object
#  8   pageId          990 non-null    float64
#  9   postId          990 non-null    float64
#  10  shares          975 non-null    float64
#  11  text            950 non-null    object
#  12  thumb           996 non-null    object
#  13  time            1000 non-null   object
#  14  timestamp       1000 non-null   int64
#  15  topLevelUrl     990 non-null    object
#  16  translatedText  12 non-null     object
# ...

# %%
data.shape
# Out:
# (1000, 18)

# %%
temp_data = data.append(data)
temp_data.shape
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_2908\2970796632.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_data = data.append(data)
# (2000, 18)

# %%
temp_data = temp_data.drop_duplicates()
temp_data.shape
# Out:
# (1000, 18)

# %%
data.columns
# Out:
# Index(['comments', 'facebookUrl', 'images/0/thumb', 'images/1/thumb',
#        'images/2/thumb', 'isVideo', 'likes', 'link', 'pageId', 'postId',
#        'shares', 'text', 'thumb', 'time', 'timestamp', 'topLevelUrl',
#        'translatedText', 'url'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# comments           24
# facebookUrl         0
# images/0/thumb    934
# images/1/thumb    997
# images/2/thumb    999
# isVideo           354
# likes               0
# link              662
# pageId             10
# postId             10
# shares             25
# text               50
# thumb               4
# time                0
# timestamp           0
# topLevelUrl        10
# translatedText    988
# url                 0
# dtype: int64

# %%
fb = pd.DataFrame().assign(date=data["time"],likes=data["likes"],comments=data["comments"],shares=data["shares"],text=data["text"],isVideo=data["isVideo"],url=data["url"])

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, nan to Localiza's photo.
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      1000 non-null   object
#  1   likes     1000 non-null   int64
#  2   comments  976 non-null    float64
#  3   shares    975 non-null    float64
#  4   text      950 non-null    object
#  5   isVideo   646 non-null    object
#  6   url       1000 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 94.8+ KB

# %%
likes = fb["likes"]

# %%
likes.mean()
# Out:
# 1588.087

# %%
fb.describe()
# Out:
#               likes    comments       shares
# count   1000.000000  976.000000   975.000000
# mean    1588.087000   56.334016   100.854359
# std     2899.741255  118.124502   268.291597
# min        2.000000    1.000000     1.000000
# 25%      116.750000    9.000000     7.000000
# 50%      348.500000   19.000000    20.000000
# 75%     1525.000000   42.000000    76.500000
# max    30000.000000  951.000000  3800.000000

# %%
fb.date = pd.to_datetime(fb.date)
fb.head()
# Out:
#                    date  likes  comments  shares  \
# alt
# NaN 2023-01-04 10:06:00      2       1.0     NaN
# NaN 2022-12-26 11:36:00     65      16.0     NaN
# NaN 2022-12-20 11:11:00    157      20.0     4.0
# NaN 2022-12-19 06:43:00   1400      75.0   220.0
# NaN 2022-12-15 06:16:00     92      22.0     1.0
#
#                                                   text isVideo  \
# alt
# NaN  Bora conferir mais um episódio da nossa Expedi...    True
# NaN  Em 2022, criamos soluções #PraVoceChegarLa. Em...    True
# NaN  Além de alugar o carro ideal, a gente também c...    True
# NaN  Oui! A Localiza tá na França. 🚙🇫🇷 ​ Fazer a vi...    True
# NaN  Alugar um carro ou assinar um 0km e pegar a es...    True
#
#                                                    url
# alt
# NaN  https://www.facebook.com/Localiza/posts/pfbid0...
# NaN  https://www.facebook.com/Localiza/posts/pfbid0...
# NaN  https://www.facebook.com/Localiza/posts/pfbid0...
# ...

# %%
fb["year"]=pd.DatetimeIndex(fb["date"]).year
fb["month"]=pd.DatetimeIndex(fb["date"]).month
fb
# Out:
#                                                date  likes  comments  shares  \
# alt
# NaN                             2023-01-04 10:06:00      2       1.0     NaN
# NaN                             2022-12-26 11:36:00     65      16.0     NaN
# NaN                             2022-12-20 11:11:00    157      20.0     4.0
# NaN                             2022-12-19 06:43:00   1400      75.0   220.0
# NaN                             2022-12-15 06:16:00     92      22.0     1.0
# ...                                             ...    ...       ...     ...
# NaN                             2017-04-11 18:00:00  19000     906.0   187.0
# NaN                             2017-04-11 13:14:00   4200      13.0    32.0
# NaN                             2017-04-10 15:17:00  26000     113.0   204.0
# No photo description available. 2017-04-10 14:17:00    235       3.0     6.0
# Localiza's photo.               2017-04-11 14:20:00    554      27.0    60.0
#
# ...

# %%
fb["monthAndYear"] = pd.to_datetime(fb.year.astype(str) + '/' + fb.month.astype(str) + '/01')

fb
# Out:
#                                                date  likes  comments  shares  \
# alt
# NaN                             2023-01-04 10:06:00      2       1.0     NaN
# NaN                             2022-12-26 11:36:00     65      16.0     NaN
# NaN                             2022-12-20 11:11:00    157      20.0     4.0
# NaN                             2022-12-19 06:43:00   1400      75.0   220.0
# NaN                             2022-12-15 06:16:00     92      22.0     1.0
# ...                                             ...    ...       ...     ...
# NaN                             2017-04-11 18:00:00  19000     906.0   187.0
# NaN                             2017-04-11 13:14:00   4200      13.0    32.0
# NaN                             2017-04-10 15:17:00  26000     113.0   204.0
# No photo description available. 2017-04-10 14:17:00    235       3.0     6.0
# Localiza's photo.               2017-04-11 14:20:00    554      27.0    60.0
#
# ...

# %%
fb.describe()
# Out:
#               likes    comments       shares         year        month
# count   1000.000000  976.000000   975.000000  1000.000000  1000.000000
# mean    1588.087000   56.334016   100.854359  2019.289000     6.750000
# std     2899.741255  118.124502   268.291597     1.660191     3.077169
# min        2.000000    1.000000     1.000000  2017.000000     1.000000
# 25%      116.750000    9.000000     7.000000  2018.000000     4.750000
# 50%      348.500000   19.000000    20.000000  2019.000000     7.000000
# 75%     1525.000000   42.000000    76.500000  2021.000000     9.000000
# max    30000.000000  951.000000  3800.000000  2023.000000    12.000000

# %%
fb.plot(kind="area",x="monthAndYear",y="likes")
# Out:
# <AxesSubplot:xlabel='monthAndYear'>

# %%
import matplotlib.pyplot as plt

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, nan to Localiza's photo.
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1000 non-null   datetime64[ns]
#  1   likes         1000 non-null   int64
#  2   comments      976 non-null    float64
#  3   shares        975 non-null    float64
#  4   text          950 non-null    object
#  5   isVideo       646 non-null    object
#  6   url           1000 non-null   object
#  7   year          1000 non-null   int64
#  8   month         1000 non-null   int64
#  9   monthAndYear  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(3), object(3)
# memory usage: 118.2+ KB

# %%
import texthero as hero

# %%
fb["text"] = fb["text"].astype("string")
fb.dtypes
# Out:
# date            datetime64[ns]
# likes                    int64
# comments               float64
# shares                 float64
# text                    string
# isVideo                 object
# url                     object
# year                     int64
# month                    int64
# monthAndYear    datetime64[ns]
# dtype: object

# %%
fb
# Out:
#                                                date  likes  comments  shares  \
# alt
# NaN                             2023-01-04 10:06:00      2       1.0     NaN
# NaN                             2022-12-26 11:36:00     65      16.0     NaN
# NaN                             2022-12-20 11:11:00    157      20.0     4.0
# NaN                             2022-12-19 06:43:00   1400      75.0   220.0
# NaN                             2022-12-15 06:16:00     92      22.0     1.0
# ...                                             ...    ...       ...     ...
# NaN                             2017-04-11 18:00:00  19000     906.0   187.0
# NaN                             2017-04-11 13:14:00   4200      13.0    32.0
# NaN                             2017-04-10 15:17:00  26000     113.0   204.0
# No photo description available. 2017-04-10 14:17:00    235       3.0     6.0
# Localiza's photo.               2017-04-11 14:20:00    554      27.0    60.0
#
# ...

# %% [markdown]
# #Removendo emoji do texto
# from cleantext import clean
# text = fb["text"]
# clean(text, no_emoji=True)
# fb["text"] = text

# %%
fb
# Out:
#                                                date  likes  comments  shares  \
# alt
# NaN                             2023-01-04 10:06:00      2       1.0     NaN
# NaN                             2022-12-26 11:36:00     65      16.0     NaN
# NaN                             2022-12-20 11:11:00    157      20.0     4.0
# NaN                             2022-12-19 06:43:00   1400      75.0   220.0
# NaN                             2022-12-15 06:16:00     92      22.0     1.0
# ...                                             ...    ...       ...     ...
# NaN                             2017-04-11 18:00:00  19000     906.0   187.0
# NaN                             2017-04-11 13:14:00   4200      13.0    32.0
# NaN                             2017-04-10 15:17:00  26000     113.0   204.0
# No photo description available. 2017-04-10 14:17:00    235       3.0     6.0
# Localiza's photo.               2017-04-11 14:20:00    554      27.0    60.0
#
# ...

# %%
fb["text"] = fb["text"].fillna(" ")
fb
# Out:
#                                                date  likes  comments  shares  \
# alt
# NaN                             2023-01-04 10:06:00      2       1.0     NaN
# NaN                             2022-12-26 11:36:00     65      16.0     NaN
# NaN                             2022-12-20 11:11:00    157      20.0     4.0
# NaN                             2022-12-19 06:43:00   1400      75.0   220.0
# NaN                             2022-12-15 06:16:00     92      22.0     1.0
# ...                                             ...    ...       ...     ...
# NaN                             2017-04-11 18:00:00  19000     906.0   187.0
# NaN                             2017-04-11 13:14:00   4200      13.0    32.0
# NaN                             2017-04-10 15:17:00  26000     113.0   204.0
# No photo description available. 2017-04-10 14:17:00    235       3.0     6.0
# Localiza's photo.               2017-04-11 14:20:00    554      27.0    60.0
#
# ...

# %%
#retirando acento
def tira_acento(texto):
    texto = texto.replace("á", "a").replace("ã", "a").replace("à", "a").replace("é", "e").replace("ê", "e").replace("í", "i").replace("ô", "o").replace("ó", "o").replace("õ", "o").replace("ú", "u").replace("û", "u").replace("ç", "c")
    return texto
fb["text"]=fb["text"].apply(tira_acento)
fb
# Out:
#                                                date  likes  comments  shares  \
# alt
# NaN                             2023-01-04 10:06:00      2       1.0     NaN
# NaN                             2022-12-26 11:36:00     65      16.0     NaN
# NaN                             2022-12-20 11:11:00    157      20.0     4.0
# NaN                             2022-12-19 06:43:00   1400      75.0   220.0
# NaN                             2022-12-15 06:16:00     92      22.0     1.0
# ...                                             ...    ...       ...     ...
# NaN                             2017-04-11 18:00:00  19000     906.0   187.0
# NaN                             2017-04-11 13:14:00   4200      13.0    32.0
# NaN                             2017-04-10 15:17:00  26000     113.0   204.0
# No photo description available. 2017-04-10 14:17:00    235       3.0     6.0
# Localiza's photo.               2017-04-11 14:20:00    554      27.0    60.0
#
# ...

# %%
#retirar emoji
import emoji as emj
EMOJIS = emj.UNICODE_EMOJI["en"]

def extract_emoji(fb):
    for index, row in fb.iterrows():
        for emoji in EMOJIS:
            if emoji in row["text"]:
                row["text"] = row["text"].replace(emoji, " ")
              

    extract_emoji(fb)
fb
# Out:
#                                                date  likes  comments  shares  \
# alt
# NaN                             2023-01-04 10:06:00      2       1.0     NaN
# NaN                             2022-12-26 11:36:00     65      16.0     NaN
# NaN                             2022-12-20 11:11:00    157      20.0     4.0
# NaN                             2022-12-19 06:43:00   1400      75.0   220.0
# NaN                             2022-12-15 06:16:00     92      22.0     1.0
# ...                                             ...    ...       ...     ...
# NaN                             2017-04-11 18:00:00  19000     906.0   187.0
# NaN                             2017-04-11 13:14:00   4200      13.0    32.0
# NaN                             2017-04-10 15:17:00  26000     113.0   204.0
# No photo description available. 2017-04-10 14:17:00    235       3.0     6.0
# Localiza's photo.               2017-04-11 14:20:00    554      27.0    60.0
#
# ...

# %% [markdown]
# #altera tudo para string
# fb = fb.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
# fb

# %%
fb = fb.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
fb
# Out:
#                                                 date  likes comments shares  \
# alt
# NaN                              2023-01-04 10:06:00      2      1.0    nan
# NaN                              2022-12-26 11:36:00     65     16.0    nan
# NaN                              2022-12-20 11:11:00    157     20.0    4.0
# NaN                              2022-12-19 06:43:00   1400     75.0  220.0
# NaN                              2022-12-15 06:16:00     92     22.0    1.0
# ...                                              ...    ...      ...    ...
# NaN                              2017-04-11 18:00:00  19000    906.0  187.0
# NaN                              2017-04-11 13:14:00   4200     13.0   32.0
# NaN                              2017-04-10 15:17:00  26000    113.0  204.0
# No photo description available.  2017-04-10 14:17:00    235      3.0    6.0
# Localiza's photo.                2017-04-11 14:20:00    554     27.0   60.0
#
# ...

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, nan to Localiza's photo.
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1000 non-null   object
#  1   likes         1000 non-null   object
#  2   comments      1000 non-null   object
#  3   shares        1000 non-null   object
#  4   text          1000 non-null   object
#  5   isVideo       1000 non-null   object
#  6   url           1000 non-null   object
#  7   year          1000 non-null   object
#  8   month         1000 non-null   object
#  9   monthAndYear  1000 non-null   object
# dtypes: object(10)
# memory usage: 118.2+ KB

# %%
fb["text"] = fb["text"].astype("string")
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, nan to Localiza's photo.
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1000 non-null   object
#  1   likes         1000 non-null   object
#  2   comments      1000 non-null   object
#  3   shares        1000 non-null   object
#  4   text          1000 non-null   string
#  5   isVideo       1000 non-null   object
#  6   url           1000 non-null   object
#  7   year          1000 non-null   object
#  8   month         1000 non-null   object
#  9   monthAndYear  1000 non-null   object
# dtypes: object(9), string(1)
# memory usage: 118.2+ KB

# %%
fb["text"].StringDtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2908\3093496881.py in <module>
# ----> 1 fb["text"].StringDtype()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'StringDtype'

# %%
# Limpeza = stopwords
import nltk
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from wordcloud import WordCloud
import string
nltk.download("stopwords")
stopwords = stopwords.words("portuguese")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\carol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
fb["text"] = fb["text"].lower()
fb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2908\1063028750.py in <module>
# ----> 1 fb["text"] = fb["text"].lower()
#       2 fb
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'
